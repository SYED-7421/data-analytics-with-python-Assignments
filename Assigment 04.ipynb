# %% [markdown]
# ![image.png](attachment:image.png)![image-2.png](attachment:image-2.png)

# %% [markdown]
# Q1

# %%
student = {
    "name": "Ahmed",
    "age": 20,
    "course": "Computer Science",
    "city": "Karachi"
}

print(student["name"])
print(student["age"])
print(student["course"])
print(student["city"])
# Out:
# Ahmed
# 20
# Computer Science
# Karachi

# %% [markdown]
# Q2

# %%
car = {
    "brand": "Toyota",
    "model": "Corolla",
    "year": 2018
}

car["color"] = "White"
car["year"] = 2022

print(car)
# Out:
# {'brand': 'Toyota', 'model': 'Corolla', 'year': 2022, 'color': 'White'}

# %% [markdown]
# Q3

# %%
person = {
    "name": "Ali",
    "age": 25,
    "city": "Karachi"
}

for key, value in person.items():
    print(key, ":", value)
# Out:
# name : Ali
# age : 25
# city : Karachi

# %% [markdown]
# Q4

# %%
numbers = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4]

frequency = {}
for num in numbers:
    if num in frequency:
        frequency[num] = frequency[num] + 1
    else:
        frequency[num] = 1

print(frequency)
# Out:
# {1: 1, 2: 2, 3: 3, 4: 4}

# %% [markdown]
# Q5

# %%
sentence = input("Enter a sentence: ")
words = sentence.split()

word_count = {}
for word in words:
    if word in word_count:
        word_count[word] = word_count[word] + 1
    else:
        word_count[word] = 1

print(word_count)
# Out:
# {'hello': 2, 'hamza': 1, 'and': 1, 'ali': 1}

# %% [markdown]
# Q6

# %%
marks = {"Math": 80, "English": 70, "Physics": 90}

total = 0
for subject in marks:
    total = total + marks[subject]

average = total / len(marks)

print("Total marks:", total)
print("Average marks:", average)
# Out:
# Total marks: 240
# Average marks: 80.0

# %% [markdown]
# Q7

# %%
students = {
    "Ali": 85,
    "Sara": 92,
    "Ahmed": 78,
    "Zara": 95
}

highest_name = ""
highest_score = 0

for name, score in students.items():
    if score > highest_score:
        highest_score = score
        highest_name = name

print("Highest scoring student:", highest_name)
print("Score:", highest_score)
# Out:
# Highest scoring student: Zara
# Score: 95

# %% [markdown]
# Q8

# %%
dict1 = {"a": 1, "b": 2}
dict2 = {"c": 3, "d": 4}

merged = {}

for key, value in dict1.items():
    merged[key] = value

for key, value in dict2.items():
    merged[key] = value

print(merged)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %% [markdown]
# Q9

# %%
contacts = {}

contacts["Ali"] = "0300-1234567"
contacts["Sara"] = "0311-2345678"
contacts["Ahmed"] = "0322-3456789"

print("Contacts added:", contacts)

search_name = input("Enter name to search: ")

if search_name in contacts:
    print("Phone number:", contacts[search_name])
else:
    print("Contact not found")
# Out:
# Contacts added: {'Ali': '0300-1234567', 'Sara': '0311-2345678', 'Ahmed': '0322-3456789'}
# Phone number: 0300-1234567
