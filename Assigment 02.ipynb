# %% [markdown]
# 1. A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years. Ask user for their salary and year of service and print the net bonus amount.

# %%
salary=float(input("ENTER YOUR SALARY :"))

service_year=int(input("ENTER YOUR YEAR OF SERVICE :"))

if (service_year > 5):

    net_bonus_amount=salary*(5/100)

    print("YOUR SALARY IS :",salary)

    print("\nYOUR YEAR OF SERVICE IS:",service_year)

    print( "\nYOUR NET BONUS AMOUNT IS :",net_bonus_amount )

else:

 print("SORRY!  YOU CAN NOT GET BONUS BECAUSE YOUR YEAR OF SERVICE IS NOT MORE THAN 5 YAER")
# Out:
# YOUR SALARY IS : 20000.0
#
# YOUR YEAR OF SERVICE IS: 7
#
# YOUR NET BONUS AMOUNT IS : 1000.0

# %% [markdown]
# 2. Write a program to check whether a person is eligible for voting or not.(accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
age=int(input("ENTER YOUR AGE : "))  #18

if(age > 17):

    print("\n YOU ARE ELIGIBLE FOR VOTING ")

else:

    print("\n YOU ARE NOT ELIGIBLE FOR VOTING ")
# Out:
#  YOU ARE ELIGIBLE FOR VOTING

# %% [markdown]
# 3. Write a program to check whether a number entered by user is even or odd.

# %%
number=int(input("ENTER A NUMBER TO FIND WHETHER A NUMBER IS EVEN OR ODD :"))

if number%2==0:

    print("THIS NUMBER IS EVEN :",number)

else:

    print("THIS NUMBER IS ODD :",number)
# Out:
# THIS NUMBER IS ODD : 3

# %% [markdown]
# 4. Write a program to check whether a number is divisible by 7 or not. Show Answer

# %%
number=int(input("ENTER A NUMBER TO FIND WHETHER A NUMBER IS DIVISIBLE BY 7 :"))

if number%7==0:

    print(" YES THIS NUMBER IS DIVISIBLE BY 7 :",number)

else:

    print(" NO THIS NUMBER IS NOT DIVISIBLE BY 7 :",number)
# Out:
#  NO THIS NUMBER IS NOT DIVISIBLE BY 7 : 50

# %% [markdown]
# 5. Write a program to display "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
number=int(input("ENTER A NUMBER TO FIND WHETHER A NUMBER IS A MULTIPLE OF 5 :")) 

if number % 5 == 0: 

    print("Hello:",number)

else:

    print("Bye:",number)
# Out:
# Hello: 25

# %% [markdown]
# 6. Write a program to calculate the electricity bill (accept number of unit from user) according to the following criteria : Unit Price
# uptp 100 units no charge Next 200 units Rs 5 per unit After 200 units Rs 10 per unit (For example if input unit is 350 than total bill amount is Rs.3500 (For example if input unit is 97 than total bill amount is Rs.0 (For example if input unit is 150 than total bill amount is Rs.750

# %%
unit_number=int(input("ENTER NUMBER OF UNITS  :"))

if unit_number <= 100:

    print("NO CHARGE")

elif unit_number > 100 and unit_number <=200:

    total_bill = unit_number * 5

    print("YOUR ELECTRICITY BILL IS :",total_bill)

else:

    total_bill = unit_number * 10
    
    print("YOUR ELECTRICITY BILL IS :",total_bill)
# Out:
# YOUR ELECTRICITY BILL IS : 2010

# %% [markdown]
# 7. Write a program to display the last digit of a number.

# %%
number=int(input("ENTER A NUMBER :")) 

last_digit = number % 10

print("NUMBER IS :",number)

print("\nLAST DIGIT OF A NUMBER IS : ",last_digit)
# Out:
# NUMBER IS : 7256
#
# LAST DIGIT OF A NUMBER IS :  6

# %% [markdown]
# 9. Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
lenght=float(input("ENTER LENGTH :")) 

breadth=float(input("ENTER BREADTH :")) 

if lenght == breadth:
    
    print("IT IS SQUARE  :",lenght,breadth)

else:

    print("IT IS RECTANGLE :",lenght,breadth)
# Out:
# IT IS RECTANGLE : 2.5 2.7

# %% [markdown]
# 10. Take two int values from user and print greatest among them.

# %%
a=int(input("ENTER A NUMBER : "))

b=int(input("ENTER A NUMBER : "))

print("a :",a,"b : ",b)

if a > b :

    print("A  IS GREATER  : ",a)
else:

     print("B IS GREATER : ",b)
# Out:
# a : 3 b :  4
# B IS GREATER :  4

# %% [markdown]
# 11. A shop will give discount of 10% if the cost of purchased quantity is more than 1000. Ask user for quantity Suppose, one unit will cost 100. Judge and print total cost for user.

# %%
quantity=int(input("ENTER THE QUANTITY OF ITEMS : "))

total_cost = quantity * 100

if total_cost > 1000:

    discount = total_cost * 10 /100

    total = total_cost - discount

    print("YOUR TOTAL COST IS : ",total)

else:

    print("YOUR TOTAL COST IS : ",total_cost)
# Out:
# YOUR TOTAL COST IS :  990.0

# %% [markdown]
# 12. A school has following rules for grading system:
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
marks=int(input("ENTER YOUR MARKS : "))

if marks > 80:

    print("YOU GOT 'A' GRADE")

elif marks >= 60 and marks <= 80 :

    print("YOU GOT 'B' GRADE")

elif marks >= 50 and marks <= 60 :

    print("YOU GOT 'C' GRADE")

elif marks >= 45 and marks <= 50 :

    print("YOU GOT 'D' GRADE")

elif marks >= 25 and marks <= 45 :

    print("YOU GOT 'E' GRADE")

elif marks < 25 :

    print("YOU GOT 'F' GRADE")
# Out:
# YOU GOT 'A' GRADE

# %% [markdown]
# 13. Take input of age of 3 people by user and determine oldest and youngest among them.

# %%
age1=int(input("ENTER YOUR AGE : "))

age2=int(input("ENTER YOUR AGE : "))

age3=int(input("ENTER YOUR AGE : "))

if age1 > age2 and age1 > age3:

    oldest = age1

elif age2 > age1 and age2 > age3:

    oldest = age2

else:

    oldest = age3

if age1 < age2 and age1 < age3:

    youngest = age1
    
elif age2 < age1 and age2 < age3:

    youngest = age2

else:

    youngest = age3

print("oldest",oldest)
print("youngest",youngest)
# Out:
# oldest 20
# youngest 12

# %% [markdown]
# 14. A student will not be allowed to sit in exam if his/her attendence is less than 75%.
#
# Take following input from user
#
# Number of classes held
#
# Number of classes attended.
#
# And print
#
# percentage of class attended
#
# Is student is allowed to sit in exam or not.

# %%
classes_held = int(input("ENTER THE NUMBER OF CLASSES HELD"))

classes_attended = int(input("ENTER THE NUMBER OF CLASSES ATTENDED"))

percentage = classes_attended / classes_held *100

print("PERCENTAGE OF CLASSES ATTENDED : ", percentage)

if percentage < 75 :

    print("YOU ARE NOT ALLOWED TO SIT IN EXAM")

else:

    print("YOU ARE ALLOWED TO SIT IN EXAM")
# Out:
# PERCENTAGE OF CLASSES ATTENDED :  80.0
# YOU ARE ALLOWED TO SIT IN EXAM

# %% [markdown]
# 15. Modify the above question to allow student to sit if he/she has medical cause. Ask user if he/she has medical cause or not ( 'Y' or 'N' ) and print accordingly.

# %%
classes_held = int(input("ENTER THE NUMBER OF CLASSES HELD"))

classes_attended = int(input("ENTER THE NUMBER OF CLASSES ATTENDED"))

percentage = classes_attended / classes_held *100

print("PERCENTAGE OF CLASSES ATTENDED : ", percentage)

if percentage < 75 :

    medical_cause=input(" Do you have medical cause? ( 'Y' or 'N' ): ")

    if medical_cause == "Y":

        print("YOU ARE  ALLOWED TO SIT IN EXAM")
    
    else:    

        print("YOU ARE NOT ALLOWED TO SIT IN EXAM")

else:

    print("YOU ARE ALLOWED TO SIT IN EXAM")
# Out:
# PERCENTAGE OF CLASSES ATTENDED :  60.0
# YOU ARE NOT ALLOWED TO SIT IN EXAM

# %% [markdown]
# 16. Write a program to check if a year is leap year or not.
# If a year is divisible by 4 then it is leap year but if the year is century year like 2000, 1900, 2100 then it must be divisible by 400.

# %%
year = int(input("Enter the year"))

if year % 100 == 0:

    if year % 400 == 0:   

        print("Leap Year",year)

    else:

        print("Not Leap Year",year)

else:                        

    if year % 4 == 0:

        print("Leap Year",year)

    else:

        print("Not Leap Year",year)
# Out:
# Leap Year 2024

# %% [markdown]
# 17. Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
age = int(input("ENTER YOUR AGE : "))

gender = input("ENTER YOUR GENDER ( M or F ) : ")

marital_status = input("ENTER YOUR MARITAL STATUS ( Y or N ) : ")

if gender == "F":

    print("YOU WILL WORK ONLY IN URBAN AREA")


elif gender == "M" and age >= 20 and age <= 40:

    print("YOU MAY WORK ANYWHERE")


elif gender == "M" and age > 40 and age <= 60:

    print("YOU WILL WORK IN URBAN AREA ONLY")


else:
    
    print("ERROR")
# Out:
# YOU MAY WORK ANYWHERE
